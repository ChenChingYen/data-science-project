# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Recommendation using Spark ALS

# %% [markdown]
# this step is used to initiate a spark session in order to use pyspark functions

# %%
# !pip install findspark
# Out:
# Requirement already satisfied: findspark in /usr/local/lib/python3.10/dist-packages (2.0.1)

# %%
# !pip install pyspark py4j
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (0.10.9.7)

# %%
import numpy as np
import json
import findspark

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import types as T

# %%
file_path_prefix = "/content/drive/MyDrive/datasets/sampled-data/"

file1_name = "filtered-sampled-cleaned-2019-Oct.csv"
file2_name = "filtered-sampled-cleaned-2019-Nov.csv"
file3_name = "filtered-sampled-cleaned-2019-Dec.csv"
file4_name = "filtered-sampled-cleaned-2020-Jan.csv"
file5_name = "filtered-sampled-cleaned-2020-Feb.csv"
file6_name = "filtered-sampled-cleaned-2020-Mar.csv"
file7_name = "filtered-sampled-cleaned-2020-Apr.csv"

filename_list = [file1_name, file2_name, file3_name, file4_name, file5_name, file6_name, file7_name]

# %%
spark = SparkSession.builder.appName("PySpark ALS").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://3a363f9aa58f:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySpark ALS</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
customSchema = T.StructType([
    T.StructField("user_id", T.IntegerType(), True),
    T.StructField("product_id", T.IntegerType(), True),
    T.StructField("rating", T.IntegerType(), True),
])

# %% [markdown]
# # Implement Matrix Factorization using SparkALS

# %% [markdown]
# this is where matrix factorization being implemented to get the user embedding and product embedding in 10 dimensional space.

# %%
from pyspark.ml.recommendation import ALS

# %%
# configure a ALS spark model
als = ALS(
    maxIter = 5,
    regParam = 0.01,
    userCol = "user_id",
    itemCol = "product_id",
    ratingCol = "rating",
    coldStartStrategy = "drop"
)

# %% [markdown]
# extract ratings grouped by user and product

# %%
chunk_size = 1000000

columns_to_load = ["product_id", "user_id", "rating"]
user_product_rating_df = pd.DataFrame(columns=columns_to_load)

for filename in filename_list:

  # load dataset in chunks
  chunks = pd.read_csv(file_path_prefix + filename, chunksize=chunk_size)
  print(f"reading {filename}", end="")

  for index, chunk in enumerate(chunks):
    user_product_rating_df = pd.concat([user_product_rating_df, chunk], ignore_index=True)

  print(f"\n{filename} completed")
# Out:
# reading filtered-sampled-cleaned-2019-Oct.csv
# filtered-sampled-cleaned-2019-Oct.csv completed
# reading filtered-sampled-cleaned-2019-Nov.csv
# filtered-sampled-cleaned-2019-Nov.csv completed
# reading filtered-sampled-cleaned-2019-Dec.csv
# filtered-sampled-cleaned-2019-Dec.csv completed
# reading filtered-sampled-cleaned-2020-Jan.csv
# filtered-sampled-cleaned-2020-Jan.csv completed
# reading filtered-sampled-cleaned-2020-Feb.csv
# filtered-sampled-cleaned-2020-Feb.csv completed
# reading filtered-sampled-cleaned-2020-Mar.csv
# filtered-sampled-cleaned-2020-Mar.csv completed
# reading filtered-sampled-cleaned-2020-Apr.csv
# filtered-sampled-cleaned-2020-Apr.csv completed

# %%
# group the user and product based on user_id and product_id by rating summation
user_product_rating_df = user_product_rating_df.groupby(
    ['user_id', 'product_id'],
    as_index=False
    )['rating'].sum()

# %%
# # normalise
# global_min = user_product_rating_df["rating"].min()
# global_max = user_product_rating_df["rating"].max()
# print(f"min: {global_min}, max: {global_max}")
# Out:
# min: 1, max: 253

# %%
# user_product_rating_df["rating"] = user_product_rating_df["rating"].map(lambda x:
#  (x - global_min)/(global_max - global_min)
# )

# %%
user_product_rating_df
# Out:
#             user_id  product_id  rating
# 0          12511517   100042492       1
# 1          29515875     1801638       1
# 2          31198833     1003549       1
# 3          34526405    18600003       1
# 4          34916060    12600007       1
# ...             ...         ...     ...
# 12670555  649774322   100143628       1
# 12670556  649774322   100143638       1
# 12670557  649774789   100142959       1
# 12670558  649774866    45400088       1
# 12670559  649774866    45400137       1
#
# [12670560 rows x 3 columns]

# %%
# user_product_rating_df.to_csv(f"{file_path_prefix}user-product-rating.csv", index=False, header=True)

# %%
# print(f"{file_path_prefix}user-product-rating.csv")
# Out:
# /content/drive/MyDrive/datasets/sampled-data/user-product-rating.csv

# %%
spark_df = spark.createDataFrame(user_product_rating_df, schema=customSchema)

# %%
model = als.fit(spark_df)

# %% [markdown]
# # Store User Embedding

# %% [markdown]
# the calculated user embedding is exported into a .parquet format file

# %%
model.userFactors.show(5)
# Out:
# +---------+--------------------+
# |       id|            features|
# +---------+--------------------+
# | 34916060|[0.32710588, 0.00...|
# | 62336140|[0.07852814, -0.3...|
# |104397540|[-0.15077847, -0....|
# |106416780|[0.36028907, -0.0...|
# |110773810|[-0.07616552, 0.0...|
# +---------+--------------------+
# only showing top 5 rows

# %%
model.userFactors.count()
# Out:
# 4175116

# %%
model.userFactors.write.parquet("/content/drive/MyDrive/spark-model/userFactors.parquet")

# %%
parquet_user = spark.read.parquet("/content/drive/MyDrive/spark-model/userFactors.parquet")
parquet_user.printSchema()
parquet_user.show(5)

# %% [markdown]
# # Store Item Embedding

# %% [markdown]
# the item embedding is also exported into a .parquet file format

# %%
model.itemFactors.show(5)
# Out:
# +-------+--------------------+
# |     id|            features|
# +-------+--------------------+
# |1001440|[0.014171817, 0.3...|
# |1001820|[0.150131, 0.2934...|
# |1002100|[-0.18513426, -0....|
# |1002310|[-0.097115144, 0....|
# |1002460|[0.054038845, 0.6...|
# +-------+--------------------+
# only showing top 5 rows

# %%
model.itemFactors.count()
# Out:
# 209271

# %%
model.itemFactors.toPandas().to_csv("/content/drive/MyDrive/spark-model/spark-item-embedding.csv", index=False, header=True)

# %%
model.itemFactors.write.parquet("/content/drive/MyDrive/spark-model/itemFactors.parquet")

# %%
parquet_item = spark.read.parquet("/content/drive/MyDrive/spark-model/itemFactors.parquet")
parquet_item.printSchema()
parquet_item.show(5)

# %% [markdown]
# # Calculate the Top 5 favourite Products of a User
# **steps:**
# 1. get the selected user embedding
# 2. calculate the cosine similarity values between that user embedding with all the product embeddings
# 3. filter out the purchased products
# 4. pick the top N products

# %% [markdown]
# # Loading user and item embedding data

# %%
df_product_embedding = pd.read_csv("/content/drive/MyDrive/spark-model/spark-item-embedding.csv")

# %%
parquet_user = spark.read.parquet("/content/drive/MyDrive/spark-model/userFactors.parquet")
parquet_item = spark.read.parquet("/content/drive/MyDrive/spark-model/itemFactors.parquet")

# %%
# df_user_embedding["features"] = df_user_embedding["features"].map(lambda x: np.array(json.loads(x)))
df_product_embedding["features"] = df_product_embedding["features"].map(lambda x: np.array(json.loads(x)))

# %% [markdown]
# Select a User

# %%
purchase_df = pd.DataFrame(pd.read_csv("/content/drive/MyDrive/datasets/sampled-data/purchase_history.csv"))

# %%
selected_user_id = 567950899

# %%
selected_user_embedding = parquet_user.filter(parquet_user["id"] == selected_user_id).toPandas()
selected_user_embedding
# Out:
#           id                                           features
# 0  567950899  [1.7456978559494019, -0.37916985154151917, -1....

# %%
purchased_by_user_df = purchase_df[purchase_df["user_id"] == selected_user_id]
purchased_by_user_df
# Out:
#                      event_time  product_id    user_id
# 118628  2019-11-30 17:18:17 UTC     1002544  567950899

# %% [markdown]
# # Calculate the Similarity between User Embedding and Product Embeddings

# %% [markdown]
# in this step, the distance library from scipy is used to calculate the cosine similarity between user embedding with each item embedding in 10 dimensional space.

# %%
from scipy.spatial import distance

# %%
df_product_embedding["similarity"] = df_product_embedding["features"].apply(
    lambda x: 1 - distance.cosine(
        selected_user_embedding.iloc[0]["features"],x
        )
)

# %%
df_product_embedding.head(5)
# Out:
#    Unnamed: 0       id                                           features  \
# 0           0  1001440  [-0.7812828421592712, 0.2694493234157562, 0.01...
# 1           1  1001820  [-0.3348201513290405, 0.10412280261516571, -0....
# 2           2  1002100  [0.0010078996419906616, -0.13538743555545807, ...
# 3           3  1002310  [-0.13170188665390015, 0.19735312461853027, -0...
# 4           4  1002460  [0.4232328236103058, 0.4985388219356537, -0.37...
#
#    similarity
# 0    0.237662
# 1    0.273127
# 2    0.817165
# 3   -0.008945
# 4   -0.192992

# %% [markdown]
# # Picked the Top N products

# %% [markdown]
# the similarity scores calculated previously are filtered and sorted

# %%
purchase_df = pd.DataFrame(pd.read_csv("/content/drive/MyDrive/purchase-data.csv"))
purchased_by_user_list = purchase_df[purchase_df["user_id"] == selected_user_id]["product_id"].tolist()

# %%
df_target_product_id = (
    df_product_embedding[~df_product_embedding["id"]
                         .isin(purchased_by_user_list)]
    .sort_values(by="similarity", ascending=False)
    .head(50)[["id", "similarity"]]
)

# %%
df_target_product_id.head(5)
# Out:
#                id  similarity
# 38333   100116101    0.955521
# 71182    26405343    0.937367
# 189186    2600939    0.931020
# 101598  100129684    0.929368
# 142331  100097646    0.927199

# %% [markdown]
# # Print All Details of the top N recommended products

# %%
products_df = pd.DataFrame(pd.read_csv("/content/drive/MyDrive/datasets/sampled-data/sampled-product-dataset.csv"))

# %%
pd.merge(
    left = df_target_product_id,
    right = products_df,
    left_on = "id",
    right_on = "product_id"
)[["product_id", "category_code", "brand", "price", "similarity"]]
# Out:
#     product_id                      category_code                  brand  \
# 0    100116101     construction.components.faucet                sokolov
# 1     26405343      computers.peripherals.printer           robertobravo
# 2      2600939   appliances.kitchen.refrigerators                 gefest
# 3    100129684           medicine.tools.tonometer                witerra
# 4    100097646                      sport.bicycle                defacto
# 5    100010405        furniture.living_room.chair                   ikea
# 6    100083459            furniture.kitchen.table               totolink
# 7    100202210                 electronics.clocks                certina
# 8      2900583       appliances.kitchen.microwave             electrolux
# 9     14000417       appliances.personal.massager               cersanit
# 10   100106291        electronics.audio.headphone                   asus
# 11     7006299                      kids.carriage                 indigo
# 12   100118592      computers.peripherals.printer               imperial
# 13   100141602     construction.components.faucet                 favory
# 14    14100667         electronics.audio.acoustic                 yamaha
# 15   100078792            furniture.kitchen.chair                 m-city
# 16   100038506        auto.accessories.compressor                sokolov
# 17     4800948        electronics.audio.headphone                     hp
# 18   100044533             apparel.shoes.step_ins               zhejiang
# 19   100009796                  apparel.underwear                  reima
# 20   100187798             auto.accessories.light                   depo
# 21    13100782           appliances.ironing_board                   rial
# 22    37500707                    accessories.bag                carters
# 23    37500138                    accessories.bag                carters
# 24    21000286                    accessories.bag                 xiaomi
# 25   100134190                      apparel.shoes                nexpero
# 26   100102519           construction.tools.light                    jet
# 27   100073544    appliances.kitchen.meat_grinder                respect
# 28   100097492            furniture.kitchen.table                defacto
# 29   100125547      computers.peripherals.printer                sokolov
# 30   100064018                      apparel.shirt                 turtle
# 31    18300243                    accessories.bag              manhattan
# 32    28719773                 apparel.shoes.keds                 tesoro
# 33   100082315          furniture.bathroom.toilet              aquarodos
# 34    19001386        computers.components.cooler                 blanco
# 35    26402357      computers.peripherals.printer                efremov
# 36    28721101                      apparel.shoes                 rieker
# 37    20000718          appliances.kitchen.kettle  sksportivnaakollekcia
# 38    25504169            furniture.kitchen.table                 febest
# 39   100168299            furniture.bathroom.bath                   fila
# 40    28700019                 apparel.shoes.keds                   spur
# 41   100056558          appliances.kitchen.juicer                samsung
# 42    28716992                      apparel.shoes                respect
# 43    12100821                        kids.skates                 altair
# 44   100024695                          sport.ski                fischer
# 45   100135785     construction.components.faucet                sokolov
# 46   100061803          furniture.bedroom.blanket                sokolov
# 47   100047286                  apparel.underwear              industria
# 48    17600933                      apparel.shoes                origins
# 49    11500673  computers.components.power_supply                   sony
#
#       price  similarity
# 0    155.91    0.955521
# 1   1582.13    0.937367
# 2    229.32    0.931020
# 3     12.10    0.929368
# 4     10.27    0.927199
# 5    303.77    0.925281
# 6     24.75    0.922676
# 7    731.04    0.922311
# 8    154.42    0.922278
# 9    316.85    0.922145
# 10   471.57    0.921604
# 11   123.53    0.921385
# 12   186.03    0.919633
# 13   165.64    0.918148
# 14   280.55    0.916604
# 15   131.79    0.916487
# 16  1069.78    0.915268
# 17    14.83    0.915018
# 18    36.04    0.914453
# 19    94.71    0.912367
# 20    77.41    0.912213
# 21  1235.55    0.912166
# 22    22.29    0.911354
# 23    36.55    0.911354
# 24    19.38    0.909899
# 25    76.96    0.907652
# 26   606.58    0.907243
# 27    55.09    0.907100
# 28     5.12    0.906756
# 29    22.78    0.906006
# 30   136.43    0.905999
# 31    25.71    0.905222
# 32    40.64    0.904873
# 33   278.26    0.904829
# 34   385.05    0.904611
# 35   178.90    0.904180
# 36    85.46    0.902939
# 37    47.62    0.902915
# 38     9.11    0.901880
# 39   205.94    0.901720
# 40    54.06    0.901409
# 41   694.51    0.901384
# 42   118.15    0.901361
# 43    38.61    0.901124
# 44   218.54    0.901087
# 45    10.55    0.900975
# 46    76.06    0.900702
# 47    20.34    0.900464
# 48    45.07    0.899956
# 49    38.59    0.899950

# %%
chunk_size = 1000000
selected_user_data = pd.DataFrame()
for filename in filename_list:
  chunks = pd.read_csv(file_path_prefix + filename, chunksize=chunk_size)
  print(f"reading {filename} ...")

  for index, chunk in enumerate(chunks):
    selected_user_data = pd.concat([selected_user_data, chunk[chunk['user_id'] == selected_user_id]], ignore_index=True)

selected_user_data
# Out:
# reading filtered-sampled-cleaned-2019-Oct.csv ...
# reading filtered-sampled-cleaned-2019-Nov.csv ...
# reading filtered-sampled-cleaned-2019-Dec.csv ...
# reading filtered-sampled-cleaned-2020-Jan.csv ...
# reading filtered-sampled-cleaned-2020-Feb.csv ...
# reading filtered-sampled-cleaned-2020-Mar.csv ...
# reading filtered-sampled-cleaned-2020-Apr.csv ...
#                  event_time event_type  product_id          category_id  \
# 0   2019-11-05 19:43:08 UTC       view     1002540  2053013555631882655
# 1   2019-11-14 20:50:00 UTC       cart     1004858  2053013555631882655
# 2   2019-11-14 20:52:15 UTC       view     1002544  2053013555631882655
# 3   2019-11-25 01:20:09 UTC       view     1002542  2053013555631882655
# 4   2019-11-24 13:19:13 UTC       view     1307401  2053013558920217191
# 5   2019-11-24 13:18:29 UTC       view     1307136  2053013558920217191
# 6   2019-11-27 12:25:32 UTC       cart     1004856  2053013555631882655
# 7   2019-11-30 17:18:17 UTC   purchase     1002544  2053013555631882655
# 8   2019-11-30 17:14:15 UTC       view     1003317  2053013555631882655
# 9   2019-11-30 17:17:54 UTC       cart     1002544  2053013555631882655
# 10  2019-11-30 23:20:07 UTC       view     1480340  2053013561092866779
# 11  2019-11-30 23:18:00 UTC       view   100010158  2053013561092866779
# 12  2019-11-30 23:31:59 UTC       view    28708419  2053013565127787455
# 13  2019-11-30 23:42:06 UTC       view    28705335  2053013565127787455
# 14  2019-11-30 23:41:08 UTC       view    28707578  2053013565127787455
# 15  2019-11-30 23:26:49 UTC       view    28722020  2053013565069067197
# 16  2019-12-15 12:26:23 UTC       cart    14300188  2053013557603205653
# 17  2020-01-07 14:07:47 UTC       view    26300102  2053013554725912943
# 18  2020-01-07 14:04:27 UTC       view    28703575  2053013565069067197
#
#                           category_code    brand    price    user_id  \
# 0                electronics.smartphone    apple   469.77  567950899
# 1                electronics.smartphone  samsung   126.00  567950899
# 2                electronics.smartphone    apple   458.10  567950899
# 3                electronics.smartphone    apple   488.51  567950899
# 4                    computers.notebook     asus   295.76  567950899
# 5                    computers.notebook     acer   514.27  567950899
# 6                electronics.smartphone  samsung   125.85  567950899
# 7                electronics.smartphone    apple   457.92  567950899
# 8                electronics.smartphone    apple  1003.89  567950899
# 9                electronics.smartphone    apple   457.92  567950899
# 10                    computers.desktop       hp  1060.26  567950899
# 11                    computers.desktop   pulser   295.99  567950899
# 12                        apparel.shoes   rooman    33.21  567950899
# 13                        apparel.shoes  respect    25.48  567950899
# 14                        apparel.shoes  respect    25.48  567950899
# 15                   apparel.shoes.keds     anta   109.37  567950899
# 16  electronics.audio.music_tools.piano  m-audio    74.88  567950899
# 17    appliances.kitchen.coffee_grinder  lucente   185.33  567950899
# 18                   apparel.shoes.keds   adidas    51.48  567950899
#
#                             user_session  rating
# 0   daf127f1-498d-496d-94d8-736e1bc324f8       1
# 1   7f7122a9-4ed0-4563-8e17-8532e3c0f627       2
# 2   7f7122a9-4ed0-4563-8e17-8532e3c0f627       1
# 3   93222d73-2da8-411a-94cc-ce24129d0cdc       1
# 4   f0e66679-efa5-4eea-afd6-cda52ee17f61       1
# 5   f0e66679-efa5-4eea-afd6-cda52ee17f61       1
# 6   bd0846ca-5f88-4eaa-8f5f-37a3457344a2       2
# 7   a1cf761a-8929-4604-b34c-e63b58de0f28       3
# 8   a1cf761a-8929-4604-b34c-e63b58de0f28       1
# 9   a1cf761a-8929-4604-b34c-e63b58de0f28       2
# 10  c99a7a2d-c640-4259-abe9-18456350474b       1
# 11  c99a7a2d-c640-4259-abe9-18456350474b       1
# 12  484ee255-1ee2-4b62-b623-d20b9fe444d1       1
# 13  593bcf0c-f2c7-42b3-95b8-4d82c1a22f16       1
# 14  593bcf0c-f2c7-42b3-95b8-4d82c1a22f16       1
# 15  484ee255-1ee2-4b62-b623-d20b9fe444d1       1
# 16  14dfacdc-61dd-4c45-8d82-7b07f72f5596       2
# 17  dff04515-81fa-4a3b-bc6c-08d0a39a1eb5       1
# 18  dff04515-81fa-4a3b-bc6c-08d0a39a1eb5       1

# %% [markdown]
# # Evaluation of Pyspark Matrix Factorization

# %% [markdown]
# this step is to evaluate the performance of the matrix factorization

# %%
from pyspark.ml.evaluation import RegressionEvaluator

# %%
(train_data, test_data) = spark_df.randomSplit([0.8, 0.2], seed=123)

model = als.fit(train_data)

predictions = model.transform(test_data)

evaluator = RegressionEvaluator(
    labelCol="rating", predictionCol="prediction", metricName="rmse"
)
rmse = evaluator.evaluate(predictions)

# %%
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Root Mean Squared Error (RMSE): 2.09552380673
